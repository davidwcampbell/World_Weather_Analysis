# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 602

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a4f1ec1d12d3d877c59f5089e4c29131

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        try:
            city_rain = city_weather["rain"]["3h"]
        except:
            city_rain = 0
        try:
            city_snow = city_weather["snow"]["3h"]
        except:
            city_snow = 0
         # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_desc,
                          "Rain inches": city_rain,
                          "Snow inches": city_snow})
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | saint-augustin
# Processing Record 3 of Set 1 | manado
# Processing Record 4 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 1 | longkou
# Processing Record 6 of Set 1 | hasaki
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | san carlos de bariloche
# Processing Record 10 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 1 | floro
# Processing Record 12 of Set 1 | asosa
# Processing Record 13 of Set 1 | iqaluit
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | ostrovnoy
# Processing Record 16 of Set 1 | magadan
# Processing Record 17 of Set 1 | victoria
# Processing Record 18 of Set 1 | beloha
# Processing Record 19 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | saskylakh
# Processing Record 22 of Set 1 | padang
# Processing Record 23 of Set 1 | novobiryusinskiy
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | butaritari
# Processing Record 27 of Set 1 | rapsani
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | olafsvik
# Processing Record 30 of Set 1 | eydhafushi
# Processing Record 31 of Set 1 | leningradskiy
# Processing Record 32 of Set 1 | nelidovo
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | qaanaaq
# Processing Record 35 of Set 1 | nikolskoye
# Processing Record 36 of Set 1 | lagoa
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | touros
# Processing Record 40 of Set 1 | hithadhoo
# Processing Record 41 of Set 1 | mayo
# Processing Record 42 of Set 1 | mahebourg
# Processing Record 43 of Set 1 | cape coast
# Processing Record 44 of Set 1 | nelson bay
# Processing Record 45 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 1 | castro
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | araouane
# Processing Record 49 of Set 1 | guasdualito
# Processing Record 50 of Set 1 | salmon arm
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 2 | rikitea
# Processing Record 4 of Set 2 | carnarvon
# Processing Record 5 of Set 2 | fort-shevchenko
# Processing Record 6 of Set 2 | chuy
# Processing Record 7 of Set 2 | san patricio
# Processing Record 8 of Set 2 | ushuaia
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | kamaishi
# Processing Record 11 of Set 2 | harper
# Processing Record 12 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | grindavik
# Processing Record 15 of Set 2 | muscat
# Processing Record 16 of Set 2 | portland
# Processing Record 17 of Set 2 | mataura
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | punta arenas
# Processing Record 20 of Set 2 | faanui
# Processing Record 21 of Set 2 | labuhan
# Processing Record 22 of Set 2 | alice springs
# Processing Record 23 of Set 2 | geraldton
# Processing Record 24 of Set 2 | bonoua
# Processing Record 25 of Set 2 | florida
# Processing Record 26 of Set 2 | dikson
# Processing Record 27 of Set 2 | cordeiro
# Processing Record 28 of Set 2 | college
# Processing Record 29 of Set 2 | thompson
# Processing Record 30 of Set 2 | kavieng
# Processing Record 31 of Set 2 | parana
# Processing Record 32 of Set 2 | inhambane
# Processing Record 33 of Set 2 | batagay-alyta
# Processing Record 34 of Set 2 | yulara
# Processing Record 35 of Set 2 | riyadh
# Processing Record 36 of Set 2 | east london
# Processing Record 37 of Set 2 | la ronge
# Processing Record 38 of Set 2 | barcelos
# Processing Record 39 of Set 2 | port alfred
# Processing Record 40 of Set 2 | umm kaddadah
# Processing Record 41 of Set 2 | point fortin
# Processing Record 42 of Set 2 | marystown
# Processing Record 43 of Set 2 | joao pessoa
# Processing Record 44 of Set 2 | lianran
# Processing Record 45 of Set 2 | farmington
# Processing Record 46 of Set 2 | cidreira
# Processing Record 47 of Set 2 | naron
# Processing Record 48 of Set 2 | cap malheureux
# Processing Record 49 of Set 2 | guarapari
# Processing Record 50 of Set 2 | barrow
# Processing Record 1 of Set 3 | erdenet
# Processing Record 2 of Set 3 | vila do maio
# Processing Record 3 of Set 3 | asau
# Processing Record 4 of Set 3 | bethel
# Processing Record 5 of Set 3 | port macquarie
# Processing Record 6 of Set 3 | moron
# Processing Record 7 of Set 3 | lebu
# Processing Record 8 of Set 3 | yellowknife
# Processing Record 9 of Set 3 | newport
# Processing Record 10 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 11 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 12 of Set 3 | abancay
# Processing Record 13 of Set 3 | jawa
# Processing Record 14 of Set 3 | saldanha
# Processing Record 15 of Set 3 | hilo
# Processing Record 16 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 3 | mar del plata
# Processing Record 18 of Set 3 | hovd
# Processing Record 19 of Set 3 | coquimbo
# Processing Record 20 of Set 3 | asyut
# Processing Record 21 of Set 3 | brae
# Processing Record 22 of Set 3 | am timan
# Processing Record 23 of Set 3 | husavik
# Processing Record 24 of Set 3 | tiksi
# Processing Record 25 of Set 3 | ribeira grande
# Processing Record 26 of Set 3 | ostersund
# Processing Record 27 of Set 3 | ilulissat
# Processing Record 28 of Set 3 | lovozero
# Processing Record 29 of Set 3 | fortuna
# Processing Record 30 of Set 3 | luderitz
# Processing Record 31 of Set 3 | aracatuba
# Processing Record 32 of Set 3 | iskateley
# Processing Record 33 of Set 3 | pochutla
# Processing Record 34 of Set 3 | gorontalo
# Processing Record 35 of Set 3 | maceio
# Processing Record 36 of Set 3 | saint-philippe
# Processing Record 37 of Set 3 | teya
# Processing Record 38 of Set 3 | myaundzha
# Processing Record 39 of Set 3 | kinsale
# Processing Record 40 of Set 3 | port elizabeth
# Processing Record 41 of Set 3 | perigueux
# Processing Record 42 of Set 3 | rio gallegos
# Processing Record 43 of Set 3 | chokurdakh
# Processing Record 44 of Set 3 | gao
# Processing Record 45 of Set 3 | vestmannaeyjar
# Processing Record 46 of Set 3 | ponta do sol
# Processing Record 47 of Set 3 | abalak
# Processing Record 48 of Set 3 | poronaysk
# Processing Record 49 of Set 3 | shingu
# Processing Record 50 of Set 3 | khatanga
# Processing Record 1 of Set 4 | doka
# Processing Record 2 of Set 4 | lompoc
# Processing Record 3 of Set 4 | santa clara
# Processing Record 4 of Set 4 | gerash
# Processing Record 5 of Set 4 | dali
# Processing Record 6 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 4 | naze
# Processing Record 8 of Set 4 | bathsheba
# Processing Record 9 of Set 4 | namatanai
# Processing Record 10 of Set 4 | norman wells
# Processing Record 11 of Set 4 | seymour
# Processing Record 12 of Set 4 | calvia
# Processing Record 13 of Set 4 | longyearbyen
# Processing Record 14 of Set 4 | cabo san lucas
# Processing Record 15 of Set 4 | poum
# Processing Record 16 of Set 4 | walvis bay
# Processing Record 17 of Set 4 | semporna
# Processing Record 18 of Set 4 | saint george
# Processing Record 19 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 4 | methoni
# Processing Record 21 of Set 4 | saint-pierre
# Processing Record 22 of Set 4 | abu samrah
# Processing Record 23 of Set 4 | taoudenni
# Processing Record 24 of Set 4 | ixtapa
# Processing Record 25 of Set 4 | zhanaozen
# Processing Record 26 of Set 4 | mlowo
# Processing Record 27 of Set 4 | navalmoral de la mata
# Processing Record 28 of Set 4 | bredasdorp
# Processing Record 29 of Set 4 | olot
# Processing Record 30 of Set 4 | lisakovsk
# Processing Record 31 of Set 4 | adrar
# Processing Record 32 of Set 4 | kuching
# Processing Record 33 of Set 4 | constantine
# Processing Record 34 of Set 4 | isangel
# Processing Record 35 of Set 4 | alofi
# Processing Record 36 of Set 4 | gubkinskiy
# Processing Record 37 of Set 4 | maujao
# City not found. Skipping...
# Processing Record 38 of Set 4 | yeppoon
# Processing Record 39 of Set 4 | auki
# Processing Record 40 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 4 | waterloo
# Processing Record 42 of Set 4 | vao
# Processing Record 43 of Set 4 | sampit
# Processing Record 44 of Set 4 | arraial do cabo
# Processing Record 45 of Set 4 | klaksvik
# Processing Record 46 of Set 4 | havelock
# Processing Record 47 of Set 4 | nishihara
# Processing Record 48 of Set 4 | qaqortoq
# Processing Record 49 of Set 4 | shizunai
# Processing Record 50 of Set 4 | te anau
# Processing Record 1 of Set 5 | san cristobal
# Processing Record 2 of Set 5 | montepuez
# Processing Record 3 of Set 5 | grand gaube
# Processing Record 4 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 5 | plattling
# Processing Record 6 of Set 5 | general roca
# Processing Record 7 of Set 5 | krasnovishersk
# Processing Record 8 of Set 5 | sterling
# Processing Record 9 of Set 5 | pevek
# Processing Record 10 of Set 5 | provideniya
# Processing Record 11 of Set 5 | nuuk
# Processing Record 12 of Set 5 | san andres
# Processing Record 13 of Set 5 | lasa
# Processing Record 14 of Set 5 | mount gambier
# Processing Record 15 of Set 5 | tuatapere
# Processing Record 16 of Set 5 | paamiut
# Processing Record 17 of Set 5 | nouadhibou
# Processing Record 18 of Set 5 | tasiilaq
# Processing Record 19 of Set 5 | aichach
# Processing Record 20 of Set 5 | katsiveli
# City not found. Skipping...
# Processing Record 21 of Set 5 | banjar
# Processing Record 22 of Set 5 | lebyazhye
# Processing Record 23 of Set 5 | aklavik
# Processing Record 24 of Set 5 | kosa
# Processing Record 25 of Set 5 | marawi
# Processing Record 26 of Set 5 | port hedland
# Processing Record 27 of Set 5 | zaton
# Processing Record 28 of Set 5 | colomi
# Processing Record 29 of Set 5 | colombo
# Processing Record 30 of Set 5 | flinders
# Processing Record 31 of Set 5 | cedar city
# Processing Record 32 of Set 5 | narsaq
# Processing Record 33 of Set 5 | dauphin
# Processing Record 34 of Set 5 | melito di porto salvo
# Processing Record 35 of Set 5 | tete
# Processing Record 36 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 5 | trinidad
# Processing Record 38 of Set 5 | villa rica
# Processing Record 39 of Set 5 | avarua
# Processing Record 40 of Set 5 | sinnamary
# Processing Record 41 of Set 5 | timbiqui
# Processing Record 42 of Set 5 | kenora
# Processing Record 43 of Set 5 | oliver
# Processing Record 44 of Set 5 | lamar
# Processing Record 45 of Set 5 | biak
# Processing Record 46 of Set 5 | port blair
# Processing Record 47 of Set 5 | nador
# Processing Record 48 of Set 5 | okhotsk
# Processing Record 49 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 5 | puerto escondido
# Processing Record 1 of Set 6 | mao
# Processing Record 2 of Set 6 | kiama
# Processing Record 3 of Set 6 | aksarka
# Processing Record 4 of Set 6 | maralal
# Processing Record 5 of Set 6 | kahului
# Processing Record 6 of Set 6 | santa rosa de viterbo
# Processing Record 7 of Set 6 | zeya
# Processing Record 8 of Set 6 | khani
# Processing Record 9 of Set 6 | lotoshino
# Processing Record 10 of Set 6 | bouloupari
# Processing Record 11 of Set 6 | kainantu
# Processing Record 12 of Set 6 | ancud
# Processing Record 13 of Set 6 | namibe
# Processing Record 14 of Set 6 | belmonte
# Processing Record 15 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 6 | tayoltita
# Processing Record 17 of Set 6 | bengkulu
# Processing Record 18 of Set 6 | vila velha
# Processing Record 19 of Set 6 | abay
# Processing Record 20 of Set 6 | muravlenko
# Processing Record 21 of Set 6 | tiznit
# Processing Record 22 of Set 6 | kangaatsiaq
# Processing Record 23 of Set 6 | hereford
# Processing Record 24 of Set 6 | ternate
# Processing Record 25 of Set 6 | mokrousovo
# Processing Record 26 of Set 6 | oktyabrskiy
# Processing Record 27 of Set 6 | vilhena
# Processing Record 28 of Set 6 | san jose
# Processing Record 29 of Set 6 | zhigansk
# Processing Record 30 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 31 of Set 6 | inta
# Processing Record 32 of Set 6 | pacifica
# Processing Record 33 of Set 6 | mount isa
# Processing Record 34 of Set 6 | talaya
# Processing Record 35 of Set 6 | pacific grove
# Processing Record 36 of Set 6 | lavrentiya
# Processing Record 37 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 38 of Set 6 | shasta lake
# Processing Record 39 of Set 6 | avera
# Processing Record 40 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 41 of Set 6 | taltal
# Processing Record 42 of Set 6 | asfi
# Processing Record 43 of Set 6 | upernavik
# Processing Record 44 of Set 6 | constitucion
# Processing Record 45 of Set 6 | praia da vitoria
# Processing Record 46 of Set 6 | pucallpa
# Processing Record 47 of Set 6 | maryville
# Processing Record 48 of Set 6 | northam
# Processing Record 49 of Set 6 | boda
# Processing Record 50 of Set 6 | matnog
# Processing Record 1 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 7 | sitka
# Processing Record 3 of Set 7 | san francisco
# Processing Record 4 of Set 7 | nkhotakota
# Processing Record 5 of Set 7 | ksenyevka
# City not found. Skipping...
# Processing Record 6 of Set 7 | lodja
# Processing Record 7 of Set 7 | fairbanks
# Processing Record 8 of Set 7 | juegang
# Processing Record 9 of Set 7 | havoysund
# Processing Record 10 of Set 7 | hojo
# Processing Record 11 of Set 7 | bukoba
# Processing Record 12 of Set 7 | rognan
# Processing Record 13 of Set 7 | souillac
# Processing Record 14 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 7 | port shepstone
# Processing Record 16 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 7 | maracaibo
# Processing Record 18 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 7 | agva
# City not found. Skipping...
# Processing Record 20 of Set 7 | camana
# Processing Record 21 of Set 7 | esperance
# Processing Record 22 of Set 7 | winnemucca
# Processing Record 23 of Set 7 | ponta delgada
# Processing Record 24 of Set 7 | tilichiki
# Processing Record 25 of Set 7 | lima
# Processing Record 26 of Set 7 | vagur
# Processing Record 27 of Set 7 | wamba
# Processing Record 28 of Set 7 | aksu
# Processing Record 29 of Set 7 | aasiaat
# Processing Record 30 of Set 7 | seydisehir
# Processing Record 31 of Set 7 | derac
# Processing Record 32 of Set 7 | kahuta
# Processing Record 33 of Set 7 | buraydah
# Processing Record 34 of Set 7 | andra
# Processing Record 35 of Set 7 | nisia floresta
# Processing Record 36 of Set 7 | altay
# Processing Record 37 of Set 7 | kavaratti
# Processing Record 38 of Set 7 | kalmunai
# Processing Record 39 of Set 7 | laguna
# Processing Record 40 of Set 7 | lorengau
# Processing Record 41 of Set 7 | quirinopolis
# Processing Record 42 of Set 7 | salinopolis
# Processing Record 43 of Set 7 | baykit
# Processing Record 44 of Set 7 | khasan
# Processing Record 45 of Set 7 | naryan-mar
# Processing Record 46 of Set 7 | sobolevo
# Processing Record 47 of Set 7 | butte
# Processing Record 48 of Set 7 | palauig
# Processing Record 49 of Set 7 | kyren
# Processing Record 50 of Set 7 | nam tha
# City not found. Skipping...
# Processing Record 1 of Set 8 | kaitangata
# Processing Record 2 of Set 8 | sarh
# Processing Record 3 of Set 8 | ciudad bolivar
# Processing Record 4 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 8 | lira
# Processing Record 6 of Set 8 | baijiantan
# Processing Record 7 of Set 8 | airai
# Processing Record 8 of Set 8 | pandamatenga
# Processing Record 9 of Set 8 | santo angelo
# Processing Record 10 of Set 8 | hofn
# Processing Record 11 of Set 8 | santa rosa
# Processing Record 12 of Set 8 | dongsheng
# Processing Record 13 of Set 8 | imbituba
# Processing Record 14 of Set 8 | lushoto
# Processing Record 15 of Set 8 | felanitx
# Processing Record 16 of Set 8 | hays
# Processing Record 17 of Set 8 | beira
# Processing Record 18 of Set 8 | broome
# Processing Record 19 of Set 8 | hastings
# Processing Record 20 of Set 8 | fort nelson
# Processing Record 21 of Set 8 | sao filipe
# Processing Record 22 of Set 8 | la palma
# Processing Record 23 of Set 8 | santa barbara
# Processing Record 24 of Set 8 | sao felix do xingu
# Processing Record 25 of Set 8 | komsomolskiy
# Processing Record 26 of Set 8 | beringovskiy
# Processing Record 27 of Set 8 | pestravka
# Processing Record 28 of Set 8 | tabuk
# Processing Record 29 of Set 8 | tura
# Processing Record 30 of Set 8 | amboasary
# Processing Record 31 of Set 8 | pangai
# Processing Record 32 of Set 8 | pinawa
# Processing Record 33 of Set 8 | zverinogolovskoye
# Processing Record 34 of Set 8 | coahuayana
# Processing Record 35 of Set 8 | vardo
# Processing Record 36 of Set 8 | marolambo
# Processing Record 37 of Set 8 | yangjiang
# Processing Record 38 of Set 8 | djougou
# Processing Record 39 of Set 8 | rehoboth
# Processing Record 40 of Set 8 | chute-aux-outardes
# Processing Record 41 of Set 8 | tucurui
# Processing Record 42 of Set 8 | severo-kurilsk
# Processing Record 43 of Set 8 | mushie
# Processing Record 44 of Set 8 | batagay
# Processing Record 45 of Set 8 | puerto baquerizo moreno
# Processing Record 46 of Set 8 | xuddur
# Processing Record 47 of Set 8 | mayumba
# Processing Record 48 of Set 8 | phetchabun
# Processing Record 49 of Set 8 | batsfjord
# Processing Record 50 of Set 8 | kapit
# Processing Record 1 of Set 9 | mosquera
# Processing Record 2 of Set 9 | martapura
# Processing Record 3 of Set 9 | muisne
# Processing Record 4 of Set 9 | lata
# Processing Record 5 of Set 9 | vladicin han
# Processing Record 6 of Set 9 | kostomuksha
# Processing Record 7 of Set 9 | kudahuvadhoo
# Processing Record 8 of Set 9 | sao joao da barra
# Processing Record 9 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 9 | salalah
# Processing Record 11 of Set 9 | port lincoln
# Processing Record 12 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 13 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 14 of Set 9 | whitehorse
# Processing Record 15 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 9 | burnie
# Processing Record 17 of Set 9 | shelbyville
# Processing Record 18 of Set 9 | hervey bay
# Processing Record 19 of Set 9 | sakaiminato
# Processing Record 20 of Set 9 | nemuro
# Processing Record 21 of Set 9 | chhoti sadri
# Processing Record 22 of Set 9 | guerrero negro
# Processing Record 23 of Set 9 | honningsvag
# Processing Record 24 of Set 9 | mocuba
# Processing Record 25 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 9 | lakkion
# Processing Record 27 of Set 9 | makakilo city
# Processing Record 28 of Set 9 | novyy svit
# Processing Record 29 of Set 9 | guican
# Processing Record 30 of Set 9 | bahia blanca
# Processing Record 31 of Set 9 | jinchengjiang
# City not found. Skipping...
# Processing Record 32 of Set 9 | mehamn
# Processing Record 33 of Set 9 | barinitas
# Processing Record 34 of Set 9 | ballina
# Processing Record 35 of Set 9 | cherskiy
# Processing Record 36 of Set 9 | vila franca do campo
# Processing Record 37 of Set 9 | clyde river
# Processing Record 38 of Set 9 | encarnacion
# Processing Record 39 of Set 9 | burns lake
# Processing Record 40 of Set 9 | gazojak
# Processing Record 41 of Set 9 | chapais
# Processing Record 42 of Set 9 | mwanza
# Processing Record 43 of Set 9 | bambous virieux
# Processing Record 44 of Set 9 | saint-georges
# Processing Record 45 of Set 9 | awjilah
# Processing Record 46 of Set 9 | praya
# Processing Record 47 of Set 9 | srednekolymsk
# Processing Record 48 of Set 9 | panguna
# Processing Record 49 of Set 9 | martinsville
# Processing Record 50 of Set 9 | angicos
# Processing Record 1 of Set 10 | la asuncion
# Processing Record 2 of Set 10 | kawalu
# Processing Record 3 of Set 10 | pisco
# Processing Record 4 of Set 10 | valle hermoso
# Processing Record 5 of Set 10 | mizdah
# Processing Record 6 of Set 10 | weyburn
# Processing Record 7 of Set 10 | saint anthony
# Processing Record 8 of Set 10 | guaratuba
# Processing Record 9 of Set 10 | kendari
# Processing Record 10 of Set 10 | mahon
# Processing Record 11 of Set 10 | timizart
# Processing Record 12 of Set 10 | luganville
# Processing Record 13 of Set 10 | ginir
# Processing Record 14 of Set 10 | muroto
# Processing Record 15 of Set 10 | forio
# Processing Record 16 of Set 10 | spring valley
# Processing Record 17 of Set 10 | kieta
# Processing Record 18 of Set 10 | turmalina
# Processing Record 19 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 20 of Set 10 | shaartuz
# City not found. Skipping...
# Processing Record 21 of Set 10 | conde
# Processing Record 22 of Set 10 | iranshahr
# Processing Record 23 of Set 10 | nizhniy tsasuchey
# Processing Record 24 of Set 10 | along
# Processing Record 25 of Set 10 | torbay
# Processing Record 26 of Set 10 | gauribidanur
# Processing Record 27 of Set 10 | ambositra
# Processing Record 28 of Set 10 | ortigueira
# Processing Record 29 of Set 10 | yomitan
# City not found. Skipping...
# Processing Record 30 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 10 | chumikan
# Processing Record 32 of Set 10 | half moon bay
# Processing Record 33 of Set 10 | ilheus
# Processing Record 34 of Set 10 | westerkappeln
# Processing Record 35 of Set 10 | bonthe
# Processing Record 36 of Set 10 | celestun
# Processing Record 37 of Set 10 | tazovskiy
# Processing Record 38 of Set 10 | lamu
# Processing Record 39 of Set 10 | banatski karlovac
# Processing Record 40 of Set 10 | egvekinot
# Processing Record 41 of Set 10 | kurchum
# Processing Record 42 of Set 10 | hounde
# Processing Record 43 of Set 10 | dunedin
# Processing Record 44 of Set 10 | labrea
# Processing Record 45 of Set 10 | cururupu
# Processing Record 46 of Set 10 | nioro
# Processing Record 47 of Set 10 | ilhabela
# Processing Record 48 of Set 10 | port-gentil
# Processing Record 49 of Set 10 | san-pedro
# Processing Record 50 of Set 10 | bongandanga
# Processing Record 1 of Set 11 | nizwa
# Processing Record 2 of Set 11 | tikamgarh
# Processing Record 3 of Set 11 | vanimo
# Processing Record 4 of Set 11 | botro
# Processing Record 5 of Set 11 | sfantu gheorghe
# Processing Record 6 of Set 11 | raga
# Processing Record 7 of Set 11 | mariinskiy posad
# Processing Record 8 of Set 11 | agadir
# Processing Record 9 of Set 11 | solwezi
# Processing Record 10 of Set 11 | pinega
# Processing Record 11 of Set 11 | sept-iles
# Processing Record 12 of Set 11 | casas grandes
# Processing Record 13 of Set 11 | killarney
# Processing Record 14 of Set 11 | chegdomyn
# Processing Record 15 of Set 11 | concordia
# Processing Record 16 of Set 11 | cartagena
# Processing Record 17 of Set 11 | hambantota
# Processing Record 18 of Set 11 | waingapu
# Processing Record 19 of Set 11 | cienega
# Processing Record 20 of Set 11 | katsuura
# Processing Record 21 of Set 11 | bela
# Processing Record 22 of Set 11 | yellapur
# Processing Record 23 of Set 11 | bucerias
# Processing Record 24 of Set 11 | marquette
# Processing Record 25 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 27 of Set 11 | samarai
# Processing Record 28 of Set 11 | khandyga
# Processing Record 29 of Set 11 | borama
# City not found. Skipping...
# Processing Record 30 of Set 11 | san vicente
# Processing Record 31 of Set 11 | barpeta
# Processing Record 32 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 33 of Set 11 | kananga
# Processing Record 34 of Set 11 | rio grande
# Processing Record 35 of Set 11 | alta floresta
# Processing Record 36 of Set 11 | manavalakurichi
# Processing Record 37 of Set 11 | kruisfontein
# Processing Record 38 of Set 11 | ialibu
# Processing Record 39 of Set 11 | gaeta
# Processing Record 40 of Set 11 | visani
# Processing Record 41 of Set 11 | custoias
# Processing Record 42 of Set 11 | hamilton
# Processing Record 43 of Set 11 | soyo
# Processing Record 44 of Set 11 | benton harbor
# Processing Record 45 of Set 11 | plouzane
# Processing Record 46 of Set 11 | olinda
# Processing Record 47 of Set 11 | yelatma
# Processing Record 48 of Set 11 | talnakh
# Processing Record 49 of Set 11 | bonavista
# Processing Record 50 of Set 11 | wanaka
# Processing Record 1 of Set 12 | narasapur
# Processing Record 2 of Set 12 | batetskiy
# Processing Record 3 of Set 12 | campbell river
# Processing Record 4 of Set 12 | salym
# Processing Record 5 of Set 12 | severo-yeniseyskiy
# Processing Record 6 of Set 12 | mandali
# Processing Record 7 of Set 12 | deputatskiy
# Processing Record 8 of Set 12 | kankakee
# Processing Record 9 of Set 12 | mudgee
# Processing Record 10 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 11 of Set 12 | sidi ali
# Processing Record 12 of Set 12 | amuntai
# Processing Record 13 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 12 | oda
# Processing Record 15 of Set 12 | koslan
# Processing Record 16 of Set 12 | kazachinskoye
# Processing Record 17 of Set 12 | orlik
# Processing Record 18 of Set 12 | pombas
# Processing Record 19 of Set 12 | markova
# Processing Record 20 of Set 12 | kayerkan
# Processing Record 21 of Set 12 | varia
# Processing Record 22 of Set 12 | port hardy
# Processing Record 23 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 24 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 25 of Set 12 | flin flon
# Processing Record 26 of Set 12 | porto walter
# Processing Record 27 of Set 12 | ouesso
# Processing Record 28 of Set 12 | guamuchil
# Processing Record 29 of Set 12 | les cayes
# Processing Record 30 of Set 12 | boguchany
# Processing Record 31 of Set 12 | arona
# Processing Record 32 of Set 12 | sabang
# Processing Record 33 of Set 12 | maldonado
# Processing Record 34 of Set 12 | berdigestyakh
# Processing Record 35 of Set 12 | kiunga
# Processing Record 36 of Set 12 | santiago
# Processing Record 37 of Set 12 | vallenar
# Processing Record 38 of Set 12 | korla
# Processing Record 39 of Set 12 | novaya mayna
# Processing Record 40 of Set 12 | dwarka
# Processing Record 41 of Set 12 | rawlins
# Processing Record 42 of Set 12 | altus
# Processing Record 43 of Set 12 | hobyo
# Processing Record 44 of Set 12 | mount abu
# Processing Record 45 of Set 12 | bolshoye ignatovo
# City not found. Skipping...
# Processing Record 46 of Set 12 | paciran
# Processing Record 47 of Set 12 | tarauaca
# Processing Record 48 of Set 12 | puerto madryn
# Processing Record 49 of Set 12 | jalu
# Processing Record 50 of Set 12 | kodinsk
# Processing Record 1 of Set 13 | calvinia
# Processing Record 2 of Set 13 | vangaindrano
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 554

# %%
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Rain inches", "Snow inches"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#              City Country                 Date    Lat     Lng  Max Temp  \
# 0       Busselton      AU  2020-05-10 20:08:31 -33.65  115.33     48.00
# 1  Saint-Augustin      CA  2020-05-10 20:09:33  51.23  -58.65     34.18
# 2          Manado      ID  2020-05-10 20:08:38   1.49  124.85     77.00
# 3         Longkou      CN  2020-05-10 20:09:33  37.65  120.33     58.26
# 4          Hasaki      JP  2020-05-10 20:09:33  35.73  140.83     69.80
#
#    Humidity  Cloudiness  Wind Speed Current Description  Rain inches  \
# 0        72          85        2.13     overcast clouds            0
# 1        91         100       12.17     overcast clouds            0
# 2        94          40        2.24    scattered clouds            0
# 3        58          22        5.50          few clouds            0
# 4        94          75        3.36       broken clouds            0
#
#    Snow inches
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
